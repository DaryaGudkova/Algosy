# %% [markdown]
# В чем разница между loc и iloc в Pandas

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35]
}, index=[10, 20, 30])
df
# Out:
#        name  age
# 10    Alice   25
# 20      Bob   30
# 30  Charlie   35

# %% [markdown]
# 🧩 Задание 1
#
# 👉
#
# Подумай:
#
# по имени индекса (20)?
#
# или по позиции?
#
# 🧩 Задание 2
#
# 👉 Получи значение 30 (возраст Bob) двумя способами:
#
# 🧩 Задание 3
#
# 👉 Что вернут эти выражения?
#
# df.loc[10:20]
# df.iloc[0:2]
#
# 💡 Вопрос: будут ли результаты одинаковыми?
#
# 🧩 Задание 4 (самое важное)
#
# 👉 Что произойдет?
#
# df.loc[0]
# df.iloc[0]
#
# Объясни почему одно работает, а другое нет

# %% [markdown]
# df.loc[0] вернет ошибку, потому что в DataFrame нет строки с индексом 0. В то время как df.iloc[0] вернет первую строку DataFrame, так как iloc использует позиционную индексацию.

# %%
# Получи строку Bob
df.loc[20], df.iloc[1]
# Out:
# (name    Bob
#  age      30
#  Name: 20, dtype: object,
#  name    Bob
#  age      30
#  Name: 20, dtype: object)

# %%
# Получи значение 30 (возраст Bob)
df.loc[20, 'age'], df.iloc[1,1]
# Out:
# (np.int64(30), np.int64(30))

# %%
df.loc[10:20], df.iloc[0:2]
# Out:
# (     name  age
#  10  Alice   25
#  20    Bob   30,
#       name  age
#  10  Alice   25
#  20    Bob   30)

# %%
#df.loc[0] #вернет ошибку, потому что в DataFrame нет строки с индексом 0. 
df.iloc[0] #В то время как df.iloc[0] вернет первую строку DataFrame, так как iloc использует позиционную индексацию.
# Out:
# name    Alice
# age        25
# Name: 10, dtype: object

# %%
class Solution:
    def hasDuplicate(self, nums: List[int]) -> bool:
